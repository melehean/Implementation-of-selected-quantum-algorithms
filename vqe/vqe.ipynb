# %%
import pennylane as qml
import matplotlib.pyplot as plt 
import functools
import pyscf
from pennylane import qchem
from pennylane import numpy as np

# %%
ATOM_1 = 'H'
ATOM_2 = 'H'
GEOMETRY_FILE = 'h2.xyz'
ELECTRON_NUMBER = 2

# %%
def changeGeometryFile(distance):
    with open(GEOMETRY_FILE, "r") as file:
        data = file.readlines()

    for index, line in enumerate(data):
        if line.startswith(ATOM_1):
                coordinates = line.split(' ')
                coordinates[-1] = str(distance) + '\n'
                newLine = ' '
                newLine = newLine.join(coordinates)
                data[index] = newLine
                break

    with open(GEOMETRY_FILE, "w") as file:
        file.writelines(data)

# %%
def getMoleculeHamiltonianCircuit(distance, mapping='jordan_wigner'):
    changeGeometryFile(distance)
    symbols, coordinates = qchem.read_structure(GEOMETRY_FILE)

    hamiltonian, qubitsNumber = qchem.molecular_hamiltonian(
        symbols,
        coordinates,
        charge=0,
        mult=1,
        basis='sto-3g',
        active_electrons=2,
        active_orbitals=2,
        mapping=mapping
    )

    return hamiltonian, qubitsNumber

# %%
def getExactEnergy(distance):
    molecule = pyscf.M(
    atom = 'H 0 0 0; H 0 0 ' + str(distance),  # in Angstrom
    basis = 'sto-3g')
    
    hartreeFockMethod = molecule.RHF().run() # restricted Hartree-Fock
    exactSolver = pyscf.fci.FCI(hartreeFockMethod)
    return exactSolver.kernel()[0]

# %%
def default(params, wires):
    qml.BasisState(np.array([1, 1, 0, 0], requires_grad=False), wires=wires)
    for i in wires:
        qml.Rot(*params[i], wires=i)
    qml.CNOT(wires=[2, 3])
    qml.CNOT(wires=[2, 0])
    qml.CNOT(wires=[3, 1])

# %%
def basic(params, wires):
    qml.BasisState(np.array([0, 0, 0, 0], requires_grad=False), wires=wires)
    for i in wires:
        qml.RX(params[i][0], wires=i)
        qml.RY(params[i][1], wires=i)
        qml.RZ(params[i][2], wires=i)

# %%
def getCostFunction(hamiltonian, device, qubitsNumber, ansatzName="default"):
    np.random.seed(0)
    if ansatzName == "default":
        params = np.random.normal(0, np.pi, (qubitsNumber, 3))  
        return qml.ExpvalCost(default, hamiltonian, device), params
    if ansatzName == "basic":
        params = np.random.normal(0, np.pi, (qubitsNumber, 3))  
        return qml.ExpvalCost(basic, hamiltonian, device), params
    if ansatzName == 'usscd':
        initial_state = qml.qchem.hf_state(ELECTRON_NUMBER, qubitsNumber)
        singles, doubles = qml.qchem.excitations(ELECTRON_NUMBER, qubitsNumber)
        s_wires, d_wires = qml.qchem.excitations_to_wires(singles, doubles)
        ansatz = functools.partial(
            qml.templates.UCCSD, init_state=initial_state, s_wires=s_wires, d_wires=d_wires
        )
        params = np.random.normal(0, np.pi, len(s_wires) + len(d_wires))
        return qml.ExpvalCost(ansatz, hamiltonian, device), params

# %%
def getOptimizer(optimizerName="GradientDescent", stepSize=0.01):
    if optimizerName == "GradientDescent":
        return qml.GradientDescentOptimizer(stepsize=stepSize)
    if optimizerName == "Adam":
        return qml.AdamOptimizer(stepsize=stepSize)
    if optimizerName == "NesterovMomentum":
        return qml.NesterovMomentumOptimizer(stepsize=stepSize)
    if optimizerName == "Adagrad":
        return qml.AdagradOptimizer(stepsize=stepSize)

# %%
def main():
    deviceName = "default.qubit" #qiskit.aer
    ansatzName = "usscd"


    optimizer = getOptimizer(optimizerName="Adam", stepSize=0.4)

    distances = np.linspace(0.1, 3.0, 30)
    energies = []
    exactEnergies = []
    accuracies = []

    for distance in distances:
        hamiltonian, qubitsNumber = getMoleculeHamiltonianCircuit(distance, 'jordan_wigner')
        device = qml.device(deviceName, wires=qubitsNumber)
        costFunction, params = getCostFunction(hamiltonian, device, qubitsNumber, ansatzName)

        max_iterations = 100

        for n in range(max_iterations):
            params, prev_energy = optimizer.step_and_cost(costFunction, params)
            energy = costFunction(params)
        
        exactEnergy = getExactEnergy(distance)
        accuracy = exactEnergy-energy

        print('Final value of the ground-state energy = {:.8f} Ha for distance {:.4f}'.format(energy,distance))
        print('Exact FCI value of the ground-state energy = {:.8f} Ha for distance {:.4f}'.format(exactEnergy,distance))
        print('Accuracy = {:.8f}'.format(np.abs(accuracy)))
        energies.append(energy)
        exactEnergies.append(exactEnergy)
        accuracies.append(accuracy)
    
    plt.plot(distances, energies)
    plt.show()
    plt.plot(distances, exactEnergies)
    plt.show()
    plt.plot(distances, accuracies)
    plt.show()

# %%
if __name__ == '__main__':
    main()
# Out:
# converged SCF energy = 2.71588739329275
# Final value of the ground-state energy = 2.71003524 Ha for distance 0.1000
# Exact FCI value of the ground-state energy = 2.70996077 Ha for distance 0.1000
# Accuracy = 0.00007446
# converged SCF energy = 0.164175012061696
# Final value of the ground-state energy = 0.15750898 Ha for distance 0.2000
# Exact FCI value of the ground-state energy = 0.15748213 Ha for distance 0.2000
# Accuracy = 0.00002684
# converged SCF energy = -0.593827758535727
# Final value of the ground-state energy = -0.60179319 Ha for distance 0.3000
# Exact FCI value of the ground-state energy = -0.60180371 Ha for distance 0.3000
# Accuracy = 0.00001052
# converged SCF energy = -0.904361394163539
# Final value of the ground-state energy = -0.91413372 Ha for distance 0.4000
# Exact FCI value of the ground-state energy = -0.91414970 Ha for distance 0.4000
# Accuracy = 0.00001599
# converged SCF energy = -1.04299627454009
# Final value of the ground-state energy = -1.05515680 Ha for distance 0.5000
# Exact FCI value of the ground-state energy = -1.05515979 Ha for distance 0.5000
# Accuracy = 0.00000299
# converged SCF energy = -1.1011282422677
# Final value of the ground-state energy = -1.11627461 Ha for distance 0.6000
# Exact FCI value of the ground-state energy = -1.11628601 Ha for distance 0.6000
# Accuracy = 0.00001140
# converged SCF energy = -1.11734903499028
# Final value of the ground-state energy = -1.13617999 Ha for distance 0.7000
# Exact FCI value of the ground-state energy = -1.13618945 Ha for distance 0.7000
# Accuracy = 0.00000947
# converged SCF energy = -1.1108503974766
# Final value of the ground-state energy = -1.13414046 Ha for distance 0.8000
# Exact FCI value of the ground-state energy = -1.13414767 Ha for distance 0.8000
# Accuracy = 0.00000721
# converged SCF energy = -1.09191404102006
# Final value of the ground-state energy = -1.12055401 Ha for distance 0.9000
# Exact FCI value of the ground-state energy = -1.12056028 Ha for distance 0.9000
# Accuracy = 0.00000628
# converged SCF energy = -1.06610864931794
# Final value of the ground-state energy = -1.10114644 Ha for distance 1.0000
# Exact FCI value of the ground-state energy = -1.10115033 Ha for distance 1.0000
# Accuracy = 0.00000389
# converged SCF energy = -1.03653887502918
# Final value of the ground-state energy = -1.07919270 Ha for distance 1.1000
# Exact FCI value of the ground-state energy = -1.07919294 Ha for distance 1.1000
# Accuracy = 0.00000025
# converged SCF energy = -1.00510670656849
# Final value of the ground-state energy = -1.05673818 Ha for distance 1.2000
# Exact FCI value of the ground-state energy = -1.05674075 Ha for distance 1.2000
# Accuracy = 0.00000257
# converged SCF energy = -0.973110615777578
# Final value of the ground-state energy = -1.03518492 Ha for distance 1.3000
# Exact FCI value of the ground-state energy = -1.03518627 Ha for distance 1.3000
# Accuracy = 0.00000135
# converged SCF energy = -0.941480654707798
# Final value of the ground-state energy = -1.01546779 Ha for distance 1.4000
# Exact FCI value of the ground-state energy = -1.01546825 Ha for distance 1.4000
# Accuracy = 0.00000046
# converged SCF energy = -0.910873554594386
# Final value of the ground-state energy = -0.99814815 Ha for distance 1.5000
# Exact FCI value of the ground-state energy = -0.99814935 Ha for distance 1.5000
# Accuracy = 0.00000121
# converged SCF energy = -0.881732449946056
# Final value of the ground-state energy = -0.98347242 Ha for distance 1.6000
# Exact FCI value of the ground-state energy = -0.98347273 Ha for distance 1.6000
# Accuracy = 0.00000031
# converged SCF energy = -0.854337626951292
# Final value of the ground-state energy = -0.97142642 Ha for distance 1.7000
# Exact FCI value of the ground-state energy = -0.97142669 Ha for distance 1.7000
# Accuracy = 0.00000027
# converged SCF energy = -0.828848147926978
# Final value of the ground-state energy = -0.96181608 Ha for distance 1.8000
# Exact FCI value of the ground-state energy = -0.96181695 Ha for distance 1.8000
# Accuracy = 0.00000087
# converged SCF energy = -0.805332844893277
# Final value of the ground-state energy = -0.95433868 Ha for distance 1.9000
# Exact FCI value of the ground-state energy = -0.95433885 Ha for distance 1.9000
# Accuracy = 0.00000017
# converged SCF energy = -0.783792654277353
# Final value of the ground-state energy = -0.94863636 Ha for distance 2.0000
# Exact FCI value of the ground-state energy = -0.94864111 Ha for distance 2.0000
# Accuracy = 0.00000476
# converged SCF energy = -0.764177651616797
# Final value of the ground-state energy = -0.94432725 Ha for distance 2.1000
# Exact FCI value of the ground-state energy = -0.94437468 Ha for distance 2.1000
# Accuracy = 0.00004743
# converged SCF energy = -0.746401349991159
# Final value of the ground-state energy = -0.94111385 Ha for distance 2.2000
# Exact FCI value of the ground-state energy = -0.94122403 Ha for distance 2.2000
# Accuracy = 0.00011019
# converged SCF energy = -0.730353321354887
# Final value of the ground-state energy = -0.93887328 Ha for distance 2.3000
# Exact FCI value of the ground-state energy = -0.93892239 Ha for distance 2.3000
# Accuracy = 0.00004910
# converged SCF energy = -0.715910060453806
# Final value of the ground-state energy = -0.93721710 Ha for distance 2.4000
# Exact FCI value of the ground-state energy = -0.93725495 Ha for distance 2.4000
# Accuracy = 0.00003786
# converged SCF energy = -0.702943599723527
# Final value of the ground-state energy = -0.93597072 Ha for distance 2.5000
# Exact FCI value of the ground-state energy = -0.93605492 Ha for distance 2.5000
# Accuracy = 0.00008420
# converged SCF energy = -0.691327561197377
# Final value of the ground-state energy = -0.93513041 Ha for distance 2.6000
# Exact FCI value of the ground-state energy = -0.93519603 Ha for distance 2.6000
# Accuracy = 0.00006562
# converged SCF energy = -0.680940760622589
# Final value of the ground-state energy = -0.93452676 Ha for distance 2.7000
# Exact FCI value of the ground-state energy = -0.93458442 Ha for distance 2.7000
# Accuracy = 0.00005766
# converged SCF energy = -0.671668859751728
# Final value of the ground-state energy = -0.93410614 Ha for distance 2.8000
# Exact FCI value of the ground-state energy = -0.93415110 Ha for distance 2.8000
# Accuracy = 0.00004496
# converged SCF energy = -0.66340474159904
# Final value of the ground-state energy = -0.93380225 Ha for distance 2.9000
# Exact FCI value of the ground-state energy = -0.93384575 Ha for distance 2.9000
# Accuracy = 0.00004351
# converged SCF energy = -0.656048251145591
# Final value of the ground-state energy = -0.93359556 Ha for distance 3.0000
# Exact FCI value of the ground-state energy = -0.93363184 Ha for distance 3.0000
# Accuracy = 0.00003629
